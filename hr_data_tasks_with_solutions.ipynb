# %%
import pandas as pd

# Load the dataset
file_path = 'hr_data_analytics.csv'
hr_data = pd.read_csv(file_path)
hr_data.head()
# Out:
#    EmployeeID              Name  Age  Gender Department              JobTitle  \
# 0           1      Norma Fisher   62    Male         IT     Financial Analyst
# 1           2    Jorge Sullivan   18    Male      Sales       Sales Executive
# 2           3   Elizabeth Woods   21  Female    Finance       Sales Executive
# 3           4      Susan Wagner   21  Female        R&D  Marketing Specialist
# 4           5  Peter Montgomery   57  Female        R&D    Research Scientist
#
#    YearsAtCompany  Salary  PerformanceScore EducationLevel MaritalStatus  \
# 0              24   65784                 1      Associate       Married
# 1               7  108247                 5       Master's      Divorced
# 2              39  170479                 5     Bachelor's      Divorced
# 3               2  115719                 4     Bachelor's      Divorced
# 4               7  127157                 2     Bachelor's        Single
#
# ...

# %% [markdown]
# ### Task 1: Filter employees who have been at the company for more than 10 years.

# %%
filtered_employees = hr_data[hr_data['YearsAtCompany'] > 10]
filtered_employees
# Out:
#       EmployeeID              Name  Age  Gender  Department  \
# 0              1      Norma Fisher   62    Male          IT
# 2              3   Elizabeth Woods   21  Female     Finance
# 5              6  Theodore Mcgrath   27  Female     Finance
# 7              8  Stephanie Sutton   39    Male         R&D
# 8              9    Brian Hamilton   54    Male   Marketing
# ...          ...               ...  ...     ...         ...
# 9994        9995      Tommy Lester   28  Female         R&D
# 9995        9996      Dylan Macias   54    Male  Operations
# 9997        9998  Mr. Daniel Gould   63    Male  Operations
# 9998        9999   Nathan Mcdonald   35    Male          IT
# 9999       10000       David Ramos   64    Male          HR
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 0        Financial Analyst              24   65784                 1
# 2          Sales Executive              39  170479                 5
# ...

# %% [markdown]
# ### Task 2: Find the average salary by department.

# %%
avg_salary_by_department = hr_data.groupby('Department')['Salary'].mean()
avg_salary_by_department
# Out:
# Department
# Finance       118737.678208
# HR            121657.212526
# IT            121552.924731
# Marketing     121016.528711
# Operations    121224.200136
# R&D           120295.071587
# Sales         118931.579164
# Name: Salary, dtype: float64

# %% [markdown]
# ### Task 3: Count the number of employees in each job title.

# %%
employee_count_by_job_title = hr_data['JobTitle'].value_counts()
employee_count_by_job_title
# Out:
# Operations Manager      1461
# Financial Analyst       1450
# Research Scientist      1448
# Sales Executive         1422
# Marketing Specialist    1415
# Software Engineer       1407
# HR Manager              1397
# Name: JobTitle, dtype: int64

# %% [markdown]
# ### Task 4: Calculate the average age of employees in each department.

# %%
avg_age_by_department = hr_data.groupby('Department')['Age'].mean()
avg_age_by_department
# Out:
# Department
# Finance       41.119484
# HR            41.195637
# IT            40.891756
# Marketing     41.051821
# Operations    40.904016
# R&D           41.391144
# Sales         41.416724
# Name: Age, dtype: float64

# %% [markdown]
# ### Task 5: Find the maximum, minimum, and average performance score.

# %%
performance_stats = hr_data['PerformanceScore'].agg(['max', 'min', 'mean'])
performance_stats
# Out:
# max     5.0000
# min     1.0000
# mean    3.0073
# Name: PerformanceScore, dtype: float64

# %% [markdown]
# ### Task 6: Filter employees who have a job satisfaction score of 4 or higher.

# %%
high_satisfaction_employees = hr_data[hr_data['JobSatisfaction'] >= 4]
high_satisfaction_employees
# Out:
#       EmployeeID               Name  Age  Gender Department  \
# 1              2     Jorge Sullivan   18    Male      Sales
# 3              4       Susan Wagner   21  Female        R&D
# 6              7  Stephanie Collins   37  Female      Sales
# 10            11         Sean Green   24  Female        R&D
# 11            12     Kimberly Smith   42  Female         IT
# ...          ...                ...  ...     ...        ...
# 9983        9984   Maria Cunningham   63  Female         IT
# 9986        9987      Daniel Larsen   20    Male  Marketing
# 9989        9990       Willie Poole   22    Male      Sales
# 9993        9994       Jeff Bennett   20    Male  Marketing
# 9998        9999    Nathan Mcdonald   35    Male         IT
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 1          Sales Executive               7  108247                 5
# 3     Marketing Specialist               2  115719                 4
# ...

# %% [markdown]
# ### Task 7: Calculate the total number of absences per department.

# %%
total_absences_by_department = hr_data.groupby('Department')['Absences'].sum()
total_absences_by_department
# Out:
# Department
# Finance       20983
# HR            21040
# IT            20437
# Marketing     21647
# Operations    20826
# R&D           19242
# Sales         21345
# Name: Absences, dtype: int64

# %% [markdown]
# ### Task 8: Find the most common education level among employees.

# %%
most_common_education = hr_data['EducationLevel'].mode()[0]
most_common_education
# Out:
# 'PhD'

# %% [markdown]
# ### Task 9: Filter employees hired after the year 2000.

# %%
employees_hired_after_2000 = hr_data[pd.to_datetime(hr_data['HireDate']).dt.year > 2000]
employees_hired_after_2000
# Out:
#       EmployeeID               Name  Age  Gender  Department  \
# 0              1       Norma Fisher   62    Male          IT
# 3              4       Susan Wagner   21  Female         R&D
# 4              5   Peter Montgomery   57  Female         R&D
# 5              6   Theodore Mcgrath   27  Female     Finance
# 6              7  Stephanie Collins   37  Female       Sales
# ...          ...                ...  ...     ...         ...
# 9990        9991        Sean Prince   49  Female  Operations
# 9992        9993       Andrea Woods   24    Male          HR
# 9995        9996       Dylan Macias   54    Male  Operations
# 9996        9997   Margaret Herrera   60    Male   Marketing
# 9998        9999    Nathan Mcdonald   35    Male          IT
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 0        Financial Analyst              24   65784                 1
# 3     Marketing Specialist               2  115719                 4
# ...

# %% [markdown]
# ### Task 10: Find the average number of years at the company for each performance score.

# %%
avg_years_by_performance_score = hr_data.groupby('PerformanceScore')['YearsAtCompany'].mean()
avg_years_by_performance_score
# Out:
# PerformanceScore
# 1    19.805894
# 2    19.667976
# 3    19.459542
# 4    20.217650
# 5    19.683714
# Name: YearsAtCompany, dtype: float64

# %% [markdown]
# ### Task 11: Calculate the average salary by gender.

# %%
avg_salary_by_gender = hr_data.groupby('Gender')['Salary'].mean()
avg_salary_by_gender
# Out:
# Gender
# Female    120316.457634
# Male      120630.641939
# Name: Salary, dtype: float64

# %% [markdown]
# ### Task 12: Find the number of employees in each marital status category.

# %%
employee_count_by_marital_status = hr_data['MaritalStatus'].value_counts()
employee_count_by_marital_status
# Out:
# Single      3384
# Married     3355
# Divorced    3261
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# ### Task 13: Calculate the average job satisfaction score by department.

# %%
avg_job_satisfaction_by_department = hr_data.groupby('Department')['JobSatisfaction'].mean()
avg_job_satisfaction_by_department
# Out:
# Department
# Finance       3.047522
# HR            3.011260
# IT            2.933333
# Marketing     3.028011
# Operations    2.988428
# R&D           3.019926
# Sales         3.006854
# Name: JobSatisfaction, dtype: float64

# %% [markdown]
# ### Task 14: Filter employees who have not been promoted in the last 5 years.

# %%
not_promoted_last_5_years = hr_data[pd.to_datetime(hr_data['LastPromotionDate']).dt.year <= 2018]
not_promoted_last_5_years
# Out:
#       EmployeeID              Name  Age  Gender  Department  \
# 1              2    Jorge Sullivan   18    Male       Sales
# 2              3   Elizabeth Woods   21  Female     Finance
# 3              4      Susan Wagner   21  Female         R&D
# 4              5  Peter Montgomery   57  Female         R&D
# 5              6  Theodore Mcgrath   27  Female     Finance
# ...          ...               ...  ...     ...         ...
# 9994        9995      Tommy Lester   28  Female         R&D
# 9995        9996      Dylan Macias   54    Male  Operations
# 9997        9998  Mr. Daniel Gould   63    Male  Operations
# 9998        9999   Nathan Mcdonald   35    Male          IT
# 9999       10000       David Ramos   64    Male          HR
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 1          Sales Executive               7  108247                 5
# 2          Sales Executive              39  170479                 5
# ...

# %% [markdown]
# ### Task 15: Calculate the correlation between age and salary.

# %%
correlation_age_salary = hr_data[['Age', 'Salary']].corr().iloc[0, 1]
correlation_age_salary
# Out:
# -0.016383914032021035

# %% [markdown]
# ### Task 16: Find the average number of absences by job satisfaction score.

# %%
avg_absences_by_job_satisfaction = hr_data.groupby('JobSatisfaction')['Absences'].mean()
avg_absences_by_job_satisfaction
# Out:
# JobSatisfaction
# 1    14.823647
# 2    14.479980
# 3    14.230809
# 4    14.758026
# 5    14.448433
# Name: Absences, dtype: float64

# %% [markdown]
# ### Task 17: Group employees by education level and find the average salary in each group.

# %%
avg_salary_by_education_level = hr_data.groupby('EducationLevel')['Salary'].mean()
avg_salary_by_education_level
# Out:
# EducationLevel
# Associate      119136.376248
# Bachelor's     120741.594608
# High School    122210.146366
# Master's       119352.900301
# PhD            120964.782673
# Name: Salary, dtype: float64

# %% [markdown]
# ### Task 18: Count the number of employees in each age group (e.g., 20-29, 30-39, etc.).

# %%
employee_count_by_age_group = pd.cut(hr_data['Age'], bins=range(20, 70, 10)).value_counts()
employee_count_by_age_group
# Out:
# (50, 60]    2174
# (20, 30]    2167
# (40, 50]    2148
# (30, 40]    2029
# Name: Age, dtype: int64

# %% [markdown]
# ### Task 19: Find the employee with the highest performance score.

# %%
highest_performance_employee = hr_data.loc[hr_data['PerformanceScore'].idxmax()]
highest_performance_employee
# Out:
# EmployeeID                         2
# Name                  Jorge Sullivan
# Age                               18
# Gender                          Male
# Department                     Sales
# JobTitle             Sales Executive
# YearsAtCompany                     7
# Salary                        108247
# PerformanceScore                   5
# EducationLevel              Master's
# MaritalStatus               Divorced
# HireDate                  1996-04-09
# LastPromotionDate         1997-10-15
# Absences                          22
# JobSatisfaction                    5
# Name: 1, dtype: object

# %% [markdown]
# ### Task 20: Filter employees who are female and have a master's degree.

# %%
female_masters_employees = hr_data[(hr_data['Gender'] == 'Female') & (hr_data['EducationLevel'] == "Master's")]
female_masters_employees
# Out:
#       EmployeeID                Name  Age  Gender Department  \
# 14            15         Dana Nguyen   19  Female         HR
# 43            44      Taylor Johnson   49  Female      Sales
# 55            56     Danielle Castro   58  Female        R&D
# 56            57      Patrick Rogers   35  Female  Marketing
# 69            70      Eric Owens PhD   64  Female         HR
# ...          ...                 ...  ...     ...        ...
# 9935        9936       Caitlin Hurst   54  Female         HR
# 9946        9947  Katherine Williams   41  Female  Marketing
# 9960        9961      Teresa Estrada   54  Female         HR
# 9962        9963        Edward Munoz   47  Female         HR
# 9983        9984    Maria Cunningham   63  Female         IT
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 14              HR Manager              36  122953                 4
# 43    Marketing Specialist              16   85694                 3
# ...

# %% [markdown]
# ### Task 21: Calculate the average performance score by marital status.

# %%
avg_performance_by_marital_status = hr_data.groupby('MaritalStatus')['PerformanceScore'].mean()
avg_performance_by_marital_status
# Out:
# MaritalStatus
# Divorced    3.039865
# Married     2.978241
# Single      3.004728
# Name: PerformanceScore, dtype: float64

# %% [markdown]
# ### Task 22: Find the department with the highest average salary.

# %%
highest_avg_salary_department = hr_data.groupby('Department')['Salary'].mean().idxmax()
highest_avg_salary_department
# Out:
# 'HR'

# %% [markdown]
# ### Task 23: Calculate the total number of years worked by all employees in the company.

# %%
total_years_worked = hr_data['YearsAtCompany'].sum()
total_years_worked
# Out:
# 197682

# %% [markdown]
# ### Task 24: Filter employees who have more than 20 absences.

# %%
more_than_20_absences = hr_data[hr_data['Absences'] > 20]
more_than_20_absences
# Out:
#       EmployeeID            Name  Age  Gender  Department  \
# 0              1    Norma Fisher   62    Male          IT
# 1              2  Jorge Sullivan   18    Male       Sales
# 3              4    Susan Wagner   21  Female         R&D
# 16            17    Walter Pratt   57  Female         R&D
# 23            24    Collin Lopez   31    Male   Marketing
# ...          ...             ...  ...     ...         ...
# 9990        9991     Sean Prince   49  Female  Operations
# 9991        9992  Brooke Leonard   64    Male          HR
# 9992        9993    Andrea Woods   24    Male          HR
# 9993        9994    Jeff Bennett   20    Male   Marketing
# 9999       10000     David Ramos   64    Male          HR
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 0        Financial Analyst              24   65784                 1
# 1          Sales Executive               7  108247                 5
# ...

# %% [markdown]
# ### Task 25: Calculate the average salary by job title.

# %%
avg_salary_by_job_title = hr_data.groupby('JobTitle')['Salary'].mean()
avg_salary_by_job_title
# Out:
# JobTitle
# Financial Analyst       120986.213793
# HR Manager              119640.272011
# Marketing Specialist    120004.633216
# Operations Manager      119352.812457
# Research Scientist      120787.121547
# Sales Executive         120279.248242
# Software Engineer       122293.852168
# Name: Salary, dtype: float64

# %% [markdown]
# ### Task 26: Find the employee with the longest tenure at the company.

# %%
longest_tenure_employee = hr_data.loc[hr_data['YearsAtCompany'].idxmax()]
longest_tenure_employee
# Out:
# EmployeeID                         3
# Name                 Elizabeth Woods
# Age                               21
# Gender                        Female
# Department                   Finance
# JobTitle             Sales Executive
# YearsAtCompany                    39
# Salary                        170479
# PerformanceScore                   5
# EducationLevel            Bachelor's
# MaritalStatus               Divorced
# HireDate                  1988-02-29
# LastPromotionDate         1995-02-14
# Absences                           9
# JobSatisfaction                    2
# Name: 2, dtype: object

# %% [markdown]
# ### Task 27: Calculate the average number of years at the company by gender.

# %%
avg_years_by_gender = hr_data.groupby('Gender')['YearsAtCompany'].mean()
avg_years_by_gender
# Out:
# Gender
# Female    19.819616
# Male      19.717903
# Name: YearsAtCompany, dtype: float64

# %% [markdown]
# ### Task 28: Find the job title with the highest average job satisfaction score.

# %%
highest_avg_satisfaction_job_title = hr_data.groupby('JobTitle')['JobSatisfaction'].mean().idxmax()
highest_avg_satisfaction_job_title
# Out:
# 'Sales Executive'

# %% [markdown]
# ### Task 29: Filter employees who have a bachelor's degree and are in the R&D department.

# %%
bachelors_r_and_d_employees = hr_data[(hr_data['EducationLevel'] == "Bachelor's") & (hr_data['Department'] == 'R&D')]
bachelors_r_and_d_employees
# Out:
#       EmployeeID              Name  Age  Gender Department  \
# 3              4      Susan Wagner   21  Female        R&D
# 4              5  Peter Montgomery   57  Female        R&D
# 92            93    David Williams   31  Female        R&D
# 114          115     Erica Jimenez   61    Male        R&D
# 116          117      Victor Nolan   20    Male        R&D
# ...          ...               ...  ...     ...        ...
# 9756        9757   Karen Macdonald   27  Female        R&D
# 9761        9762        John Price   61  Female        R&D
# 9855        9856    William Warren   21    Male        R&D
# 9877        9878     Melissa Moore   36  Female        R&D
# 9893        9894          James Le   53    Male        R&D
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 3     Marketing Specialist               2  115719                 4
# 4       Research Scientist               7  127157                 2
# ...

# %% [markdown]
# ### Task 30: Calculate the average age by marital status.

# %%
avg_age_by_marital_status = hr_data.groupby('MaritalStatus')['Age'].mean()
avg_age_by_marital_status
# Out:
# MaritalStatus
# Divorced    40.897577
# Married     41.207154
# Single      41.299350
# Name: Age, dtype: float64

# %% [markdown]
# ### Task 31: Find the department with the highest average performance score.

# %%
highest_avg_performance_department = hr_data.groupby('Department')['PerformanceScore'].mean().idxmax()
highest_avg_performance_department
# Out:
# 'Sales'

# %% [markdown]
# ### Task 32: Calculate the average number of absences by education level.

# %%
avg_absences_by_education_level = hr_data.groupby('EducationLevel')['Absences'].mean()
avg_absences_by_education_level
# Out:
# EducationLevel
# Associate      14.536926
# Bachelor's     14.551672
# High School    14.800921
# Master's       14.466433
# PhD            14.412628
# Name: Absences, dtype: float64

# %% [markdown]
# ### Task 33: Filter employees who were hired in the year 2010.

# %%
hired_in_2010 = hr_data[pd.to_datetime(hr_data['HireDate']).dt.year == 2010]
hired_in_2010
# Out:
#       EmployeeID               Name  Age  Gender  Department  \
# 146          147    Rachel Martinez   48    Male          IT
# 275          276       Olivia Gomez   57  Female          IT
# 330          331       Chelsea Dunn   50  Female          IT
# 378          379        Jimmy Moore   41  Female  Operations
# 434          435    Cassandra Silva   21  Female     Finance
# ...          ...                ...  ...     ...         ...
# 9828        9829       Mary Jackson   19    Male       Sales
# 9904        9905  Elizabeth Jackson   18    Male   Marketing
# 9933        9934   Lindsay Gonzalez   24  Female          HR
# 9954        9955        Misty Cross   29    Male  Operations
# 9971        9972       Amanda Owens   30    Male       Sales
#
#                 JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 146   Research Scientist              15   63974                 4
# 275   Research Scientist              35  187296                 5
# ...

# %% [markdown]
# ### Task 34: Calculate the average salary of employees who have been promoted in the last 3 years.

# %%
avg_salary_recent_promotions = hr_data[pd.to_datetime(hr_data['LastPromotionDate']).dt.year >= 2021]['Salary'].mean()
avg_salary_recent_promotions
# Out:
# 120950.83789192795

# %% [markdown]
# ### Task 35: Find the employee with the highest number of absences.

# %%
highest_absences_employee = hr_data.loc[hr_data['Absences'].idxmax()]
highest_absences_employee
# Out:
# EmployeeID                         27
# Name                 Sarah Villanueva
# Age                                38
# Gender                           Male
# Department                        R&D
# JobTitle              Sales Executive
# YearsAtCompany                      4
# Salary                          97230
# PerformanceScore                    1
# EducationLevel               Master's
# MaritalStatus                  Single
# HireDate                   1991-12-22
# LastPromotionDate          1999-08-09
# Absences                           29
# JobSatisfaction                     5
# Name: 26, dtype: object

# %% [markdown]
# ### Task 36: Calculate the average job satisfaction score by education level.

# %%
avg_satisfaction_by_education_level = hr_data.groupby('EducationLevel')['JobSatisfaction'].mean()
avg_satisfaction_by_education_level
# Out:
# EducationLevel
# Associate      3.024451
# Bachelor's     3.043435
# High School    2.996418
# Master's       2.982966
# PhD            2.979442
# Name: JobSatisfaction, dtype: float64

# %% [markdown]
# ### Task 37: Filter employees who have a performance score of 3 or higher and are married.

# %%
high_performance_married_employees = hr_data[(hr_data['PerformanceScore'] >= 3) & (hr_data['MaritalStatus'] == 'Married')]
high_performance_married_employees
# Out:
#       EmployeeID              Name  Age  Gender  Department  \
# 7              8  Stephanie Sutton   39    Male         R&D
# 18            19   Tasha Rodriguez   64    Male   Marketing
# 25            26    Peter Mcdowell   27  Female         R&D
# 27            28    Kimberly Myers   34    Male       Sales
# 35            36     Faith Cabrera   37    Male         R&D
# ...          ...               ...  ...     ...         ...
# 9984        9985    Ricardo Graves   33    Male  Operations
# 9985        9986     Travis Kelley   57    Male       Sales
# 9986        9987     Daniel Larsen   20    Male   Marketing
# 9988        9989    Andrea Holland   29  Female       Sales
# 9989        9990      Willie Poole   22    Male       Sales
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 7               HR Manager              27  116607                 5
# 18       Financial Analyst              19  120726                 4
# ...

# %% [markdown]
# ### Task 38: Find the department with the most employees.

# %%
most_employees_department = hr_data['Department'].value_counts().idxmax()
most_employees_department
# Out:
# 'Finance'

# %% [markdown]
# ### Task 39: Calculate the average number of years at the company by department.

# %%
avg_years_by_department = hr_data.groupby('Department')['YearsAtCompany'].mean()
avg_years_by_department
# Out:
# Department
# Finance       20.026477
# HR            19.912034
# IT            19.686022
# Marketing     19.703782
# Operations    19.565010
# R&D           19.952768
# Sales         19.542152
# Name: YearsAtCompany, dtype: float64

# %% [markdown]
# ### Task 40: Find the employee with the earliest hire date.

# %%
earliest_hire_date_employee = hr_data.loc[pd.to_datetime(hr_data['HireDate']).idxmin()]
earliest_hire_date_employee
# Out:
# EmployeeID                        1276
# Name                  Brittany Baldwin
# Age                                 53
# Gender                            Male
# Department                         R&D
# JobTitle             Financial Analyst
# YearsAtCompany                       3
# Salary                           70194
# PerformanceScore                     2
# EducationLevel              Bachelor's
# MaritalStatus                 Divorced
# HireDate                    1984-08-12
# LastPromotionDate           2001-03-15
# Absences                            20
# JobSatisfaction                      4
# Name: 1275, dtype: object

# %% [markdown]
# ### Task 41: Calculate the average salary of employees who have a job satisfaction score of 2 or lower.

# %%
avg_salary_low_satisfaction = hr_data[hr_data['JobSatisfaction'] <= 2]['Salary'].mean()
avg_salary_low_satisfaction
# Out:
# 121718.5272909364

# %% [markdown]
# ### Task 42: Find the gender distribution in each department.

# %%
gender_distribution_by_department = hr_data.groupby('Department')['Gender'].value_counts().unstack().fillna(0)
gender_distribution_by_department
# Out:
# Gender      Female  Male
# Department
# Finance        707   766
# HR             722   699
# IT             660   735
# Marketing      713   715
# Operations     696   773
# R&D            710   645
# Sales          737   722

# %% [markdown]
# ### Task 43: Calculate the total number of employees in the Sales department.

# %%
total_sales_employees = hr_data[hr_data['Department'] == 'Sales'].shape[0]
total_sales_employees
# Out:
# 1459

# %% [markdown]
# ### Task 44: Find the average number of years at the company for each marital status category.

# %%
avg_years_by_marital_status = hr_data.groupby('MaritalStatus')['YearsAtCompany'].mean()
avg_years_by_marital_status
# Out:
# MaritalStatus
# Divorced    19.638761
# Married     20.102832
# Single      19.561170
# Name: YearsAtCompany, dtype: float64

# %% [markdown]
# ### Task 45: Filter employees who have a salary greater than $100,000.

# %%
high_salary_employees = hr_data[hr_data['Salary'] > 100000]
high_salary_employees
# Out:
#       EmployeeID              Name  Age  Gender  Department  \
# 1              2    Jorge Sullivan   18    Male       Sales
# 2              3   Elizabeth Woods   21  Female     Finance
# 3              4      Susan Wagner   21  Female         R&D
# 4              5  Peter Montgomery   57  Female         R&D
# 5              6  Theodore Mcgrath   27  Female     Finance
# ...          ...               ...  ...     ...         ...
# 9992        9993      Andrea Woods   24    Male          HR
# 9993        9994      Jeff Bennett   20    Male   Marketing
# 9995        9996      Dylan Macias   54    Male  Operations
# 9996        9997  Margaret Herrera   60    Male   Marketing
# 9998        9999   Nathan Mcdonald   35    Male          IT
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 1          Sales Executive               7  108247                 5
# 2          Sales Executive              39  170479                 5
# ...

# %% [markdown]
# ### Task 46: Calculate the average performance score by job title.

# %%
avg_performance_by_job_title = hr_data.groupby('JobTitle')['PerformanceScore'].mean()
avg_performance_by_job_title
# Out:
# JobTitle
# Financial Analyst       3.005517
# HR Manager              2.978525
# Marketing Specialist    3.072792
# Operations Manager      2.993840
# Research Scientist      2.987569
# Sales Executive         3.002813
# Software Engineer       3.010661
# Name: PerformanceScore, dtype: float64

# %% [markdown]
# ### Task 47: Find the number of employees hired in each year.

# %%
employees_hired_each_year = pd.to_datetime(hr_data['HireDate']).dt.year.value_counts().sort_index()
employees_hired_each_year
# Out:
# 1984     99
# 1985    240
# 1986    271
# 1987    269
# 1988    272
# 1989    269
# 1990    235
# 1991    251
# 1992    238
# 1993    235
# 1994    258
# 1995    252
# 1996    260
# 1997    273
# 1998    243
# 1999    248
# 2000    275
# 2001    248
# 2002    221
# 2003    233
# 2004    236
# 2005    259
# 2006    263
# 2007    248
# 2008    250
# 2009    246
# 2010    251
# 2011    264
# 2012    241
# 2013    254
# 2014    247
# 2015    224
# 2016    272
# 2017    227
# 2018    245
# 2019    287
# 2020    243
# 2021    254
# 2022    214
# 2023    250
# 2024    135
# Name: HireDate, dtype: int64

# %% [markdown]
# ### Task 48: Calculate the average job satisfaction score by performance score.

# %%
avg_satisfaction_by_performance_score = hr_data.groupby('PerformanceScore')['JobSatisfaction'].mean()
avg_satisfaction_by_performance_score
# Out:
# PerformanceScore
# 1    3.044207
# 2    2.977898
# 3    3.092112
# 4    2.967278
# 5    2.948361
# Name: JobSatisfaction, dtype: float64

# %% [markdown]
# ### Task 49: Filter employees who are male and have been at the company for less than 5 years.

# %%
recent_hire_male_employees = hr_data[(hr_data['Gender'] == 'Male') & (hr_data['YearsAtCompany'] < 5)]
recent_hire_male_employees
# Out:
#       EmployeeID              Name  Age Gender  Department  \
# 9             10        Susan Levy   41   Male          IT
# 13            14      April Snyder   30   Male     Finance
# 26            27  Sarah Villanueva   38   Male         R&D
# 35            36     Faith Cabrera   37   Male         R&D
# 48            49   Nicholas Massey   46   Male         R&D
# ...          ...               ...  ...    ...         ...
# 9923        9924        Alison Kim   25   Male  Operations
# 9925        9926    Melanie Powers   47   Male     Finance
# 9929        9930   Christine Dixon   41   Male       Sales
# 9975        9976     Selena Miller   26   Male          HR
# 9980        9981    Joseph Walters   18   Male       Sales
#
#                   JobTitle  YearsAtCompany  Salary  PerformanceScore  \
# 9     Marketing Specialist               1  193913                 2
# 13      Operations Manager               1   95919                 3
# ...

# %% [markdown]
# ### Task 50: Find the employee with the most recent promotion date.

# %%
most_recent_promotion_employee = hr_data.loc[pd.to_datetime(hr_data['LastPromotionDate']).idxmax()]
most_recent_promotion_employee
# Out:
# EmployeeID                   482
# Name                 Grace Davis
# Age                           23
# Gender                      Male
# Department                   R&D
# JobTitle              HR Manager
# YearsAtCompany                25
# Salary                     68239
# PerformanceScore               3
# EducationLevel         Associate
# MaritalStatus            Married
# HireDate              2020-06-03
# LastPromotionDate     2024-08-07
# Absences                       0
# JobSatisfaction                4
# Name: 481, dtype: object
